# %%
import pandas as pd

data = {
'Email':['Win money now',
'Meeting at 5 PM',
'Claim your free prize',
'Project discussion tomorrow',
'Congratulations! You won'],

'Label':['Spam',
'Not Spam',
'Spam',
'Not Spam',
'Spam']
}

df = pd.DataFrame(data)

print(df)
# Out:
#                          Email     Label
# 0                Win money now      Spam
# 1              Meeting at 5 PM  Not Spam
# 2        Claim your free prize      Spam
# 3  Project discussion tomorrow  Not Spam
# 4     Congratulations! You won      Spam

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

vectorizer = CountVectorizer()

X = vectorizer.fit_transform(df['Email'])

model = MultinomialNB()

model.fit(X, df['Label'])

print("Model Training Complete!")
# Out:
# Model Training Complete!

# %%
new_email = ["Free money offer"]

email_data = vectorizer.transform(new_email)

prediction = model.predict(email_data)

print("Prediction =", prediction[0])
# Out:
# Prediction = Spam
